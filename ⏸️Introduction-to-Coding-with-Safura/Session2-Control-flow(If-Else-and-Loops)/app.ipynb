# %% [markdown]
# # Sufura PDF Code

# %% [markdown]
# ## Condition Statements

# %%
""" 
if condition:
    # Code block executed if condition is True
elif another_condition:
    # Code block executed if another_condition is True
else:
    # Code block executed if no condition is True 
"""

# %%
agent = 18
if agent >= 18:
    print("You are a adult.")
else:
    print("You are a minor.")
# Out:
# You are a adult.

# %% [markdown]
# ## The for Loop

# %%
""" 
for variable in sequence:
    # Code block to execute
 """
# Out:
# ' \nfor variable in sequence:\n    # Code block to execute\n '

# %%
for i in range(5):
    print("iteration:", i)

# %% [markdown]
# # Sufura Written Code

# %%
age = int(input("Enter Your age: "))
if age >= 20:
    print("You are an adult")
elif age >= 13 and age<= 19: # 13<= age <= 19
    print("You are an teenager!")
elif 0 <= age <= 12:
    print("You are a child!")
else:
    print("the input data is invalid for age.")
# Out:
# the input data is invalid for age.

# %%
for i in range(1000):
    print("Hi everyone! Welcome to the 2nd session!")
# Out:
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# Hi everyone! Welcome to the 2nd session!
# ...
