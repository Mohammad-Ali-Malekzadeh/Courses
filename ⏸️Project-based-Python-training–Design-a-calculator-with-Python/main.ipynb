# %% [markdown]
# # import

# %% [markdown]
# <p style="direction: rtl">
# کاربرد اصلی:<br>
# این ماژول برای نمایش پنجره‌های محاوره‌ای (Dialog Boxes) با پیام‌های مختلف به کاربر استفاده میشود. این پنجره‌ها معمولاً برای:<br>
# اطلاع‌رسانی (مثلاً "عملیات با موفقیت انجام شد")<br>
# اخطار (مثلاً "فیلدها را پر کنید")<br>
# خطا (مثلاً "ارتباط با سرور برقرار نشد")<br>
# سوال پرسیدن (مثلاً "آیا مطمئن هستید؟") با دکمه‌های Yes/No
# </p>

# %%
from tkinter import *
import tkinter.messagebox

# %% [markdown]
# # Settings

# %% [markdown]
# ## root = Tk()
# <p style="direction: rtl">
# این کد، پنجرهٔ اصلی (Main Window) برنامه‌های گرافیکی tkinter را می‌سازد.<br>
# برای درک بهتر، بیایید خط‌به‌خط بررسی کنیم:<br>
# ۱. Tk() چیست؟<br>
# Tk یک کلاس در ماژول tkinter است. وقتی آن را صدا می‌زنید (Tk())، یک شیء ساخته می‌شود که نمایانگر خودِ برنامه (application) و پنجرهٔ اصلی آن است.<br>
# این کار چند کار اساسی انجام می‌دهد:<br>
# یک پنجرهٔ خالی با عنوان پیش‌فرض ("tk") و اندازهٔ کوچک باز می‌کند.<br>
# یک حلقه‌ی رویداد (Event Loop) راه‌اندازی می‌کند (اگر بعداً mainloop() صدا زده شود) تا منتظر کلیک‌ها و ورودی‌های کاربر بماند.<br>
# به عنوان ظرف (Container) اصلی عمل می‌کند؛ یعنی تمام دکمه‌ها، برچسب‌ها و جعبه‌های متنی دیگر، داخل همین پنجره قرار می‌گیرند.<br>
# ۲. root = Tk() یعنی چه؟<br>
# با این کار، شیء ساخته‌شده را در متغیری به نام root ذخیره می‌کنید. این متغیر حالا به همه‌ی برنامه دسترسی دارد و شما می‌توانید با آن کار کنید
# </p>

# %%
root = Tk()
root.title("Calculator")  # تایتل برنامه مون
root.geometry("400x250")  # طول و عرض برنامه رو تنظیم میکنه
root.resizable(width=False, height=False)  # جلوی ریسایز کردن رو میگیره
# Out:
# ''

# %% [markdown]
# ## root.configure(bg=color)
# <style>
# /* تغییر پس‌زمینه تمام بلوک‌های کد در سلول‌های Markdown */
# pre, code {
#     width: 600px;
#     background-color: #000000 !important;
#     font-family: 'Fira Code', monospace;
#     padding-left: 30px
# }
#
# /* تغییر استایل یک زبان خاص، مثلاً پایتون */
# code{
#     color: #ffffff;
# }</style>
# <p style="direction: rtl">
# متد configure() چیست؟<br>
# configure یک متد قدرتمند در tkinter است که به شما اجازه می‌دهد ویژگی‌های ظاهری یک ویجت را بعد از ساخته شدن، تغییر دهید. معادل مستقیم آن، تنظیم ویژگی‌ها در زمان ساخت است:
# در اکثر ویجت‌های tkinter، هر دو کلمه bg و background معادل هم هستند و یکی را به جای دیگری هم می‌توانید استفاده کنید.
# </p>
# <div>
# <pre>
# <code class="language-python">
# # این دو خط کاملاً معادل هستند:
# root = tk.Tk(bg="gray")        # تنظیم در زمان ساخت
# root.configure(bg="gray")      # تنظیم بعد از ساخت (تغییر ویژگی)
# </code>
# </pre>
# </div>

# %%
color = "gray"
root.configure(bg=color)

# %% [markdown]
# # Variable

# %%
num1 = StringVar()
num2 = StringVar()
res = StringVar()

# %% [markdown]
# # Frames

# %% [markdown]
# <table style="direction:RTL;width: 100%; border-collapse: collapse; font-size: 15px; border-radius: 8px; overflow: hidden; border: 1px solid #ddd;">
#     <thead>
#         <tr style="background-color: #3498db; color: white;">
#             <th style="padding: 12px; text-align: right; width: 30%;">پارامتر</th>
#             <th style="padding: 12px; text-align: right; width: 70%;">توضیح</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="border-bottom: 1px solid #ddd;">
#             <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">root</code></td>
#             <td style="padding: 10px;"><strong>والد (parent)</strong> این فریم. یعنی این فریم داخل پنجره اصلی به نام <code style="padding: 3px 8px; border-radius: 4px;">root</code> قرار میگیرد.</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #ddd;">
#             <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">width=400</code></td>
#             <td style="padding: 10px;"><strong>عرض</strong> فریم به پیکسل = 400</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #ddd;">
#             <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">height=50</code></td>
#             <td style="padding: 10px;"><strong>ارتفاع</strong> فریم به پیکسل = 50</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">bg=color</code></td>
#             <td style="padding: 10px;"><strong>رنگ پس‌زمینه</strong> (background). مقدار <code style="padding: 3px 8px; border-radius: 4px;">color</code> باید یک رشته مثل <code style="padding: 3px 8px; border-radius: 4px;">"red"</code> یا <code style="padding: 3px 8px; border-radius: 4px;">"#FF0000"</code> یا متغیری که رنگ را ذخیره کرده باشد.</td>
#         </tr>
#     </tbody>
# </table>

# %%
First_frame = Frame(root, width= 400, height= 50, bg = color)
First_frame.pack(side="top")
Second_frame = Frame(root, width= 400, height= 50, bg = color)
Second_frame.pack(side="top")
Third_frame = Frame(root, width= 400, height= 50, bg = color)
Third_frame.pack(side="top")
Forth_frame = Frame(root, width= 400, height= 50, bg = color)
Forth_frame.pack(side="top")
Five_frame = Frame(root, width= 400, height= 50, bg = color)
Five_frame.pack(side="top")

# %% [markdown]
# # Buttons

# %% [markdown]
# <table style="direction:RTL;width: 100%; border-collapse: collapse; font-size: 15px; border-radius: 8px; overflow: hidden; border: 1px solid #ddd;"> <thead> <tr style="background-color: #3498db; color: white;"> <th style="padding: 12px; text-align: right; width: 25%;">بخش کد</th> <th style="padding: 12px; text-align: right; width: 75%;">توضیح</th> </tr> </thead> <tbody> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">btn_plus</code></td> <td style="padding: 10px;">نام متغیری که شیء دکمه در آن ذخیره میشود</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">Button()</code></td> <td style="padding: 10px;">کلاس سازنده دکمه در Tkinter</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">Forth_frame</code></td> <td style="padding: 10px;"><strong>والد (parent)</strong> دکمه. یعنی این دکمه داخل فریم چهارم (<code>Forth_frame</code>) قرار میگیرد</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">text="-"</code></td> <td style="padding: 10px;"><strong>متن</strong> نمایش داده شده روی دکمه = علامت منفی (-)</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">width=10</code></td> <td style="padding: 10px;"><strong>عرض</strong> دکمه = 10 واحد کاراکتری (نه پیکسل!)</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">highlightbackground=color</code></td> <td style="padding: 10px;"><strong>رنگ حاشیه</strong> دکمه وقتی فوکوس ندارد. مقدار <code>color</code> باید یک رنگ معتبر مثل <code>"red"</code> یا <code>"#FF0000"</code> باشد</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">.pack()</code></td> <td style="padding: 10px;">مدیر چیدمان <strong>pack</strong> برای قرار دادن دکمه در فریم</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">side=LEFT</code></td> <td style="padding: 10px;">دکمه در <strong>سمت چپ</strong> فریم قرار میگیرد</td> </tr> <tr style="border-bottom: 1px solid #ddd;"> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">padx=5</code></td> <td style="padding: 10px;"><strong>فاصله افقی</strong> (چپ و راست) دکمه از سایر ویجت‌ها = 5 پیکسل</td> </tr> <tr> <td style="padding: 10px;"><code style="padding: 3px 8px; border-radius: 4px; color: #d63384;">pady=5</code></td> <td style="padding: 10px;"><strong>فاصله عمودی</strong> (بالا و پایین) دکمه از سایر ویجت‌ها = 5 پیکسل</td> </tr> </tbody> </table>

# %%
btn_plus = Button(Forth_frame, text="+", width=10, highlightbackground= color, command= lambda: minus())
btn_plus.pack(side= LEFT,  padx= 5, pady= 5)
btn_plus = Button(Forth_frame, text="-", width=10, highlightbackground= color, command= lambda: plus())
btn_plus.pack(side= LEFT,  padx= 5, pady= 5)
btn_plus = Button(Forth_frame, text="*", width=10, highlightbackground= color, command= lambda: mul())
btn_plus.pack(side= LEFT,  padx= 5, pady= 5)
btn_plus = Button(Forth_frame, text="/", width=10, highlightbackground= color, command= lambda: div())
btn_plus.pack(side= LEFT,  padx= 5, pady= 5)
btn_plus = Button(Five_frame, text="Clear", width=10, highlightbackground= color, command= lambda: clear())
btn_plus.pack(side= LEFT,  padx= 5, pady= 5)
btn_plus = Button(Five_frame, text="Creator", width=10, highlightbackground= color, command= lambda: creator())
btn_plus.pack(side= LEFT,  padx= 5, pady= 5)

# %% [markdown]
# # Functions

# %%
def error_Msg(ms):
    if ms == 'error':
        tkinter.messagebox.showerror("Error", "Something Went Wrong")
    elif ms == "Division Error":
        tkinter.messagebox.showerror("Division Error", "can not divide by 0")

def plus():
    try:
        value = float(num1.get()) + float(num2.get())
        res.set(value)
    except:
        error_Msg('error')

def minus():
    try:
        value = float(num1.get()) - float(num2.get())
        res.set(value)
    except:
        error_Msg('error')

def mul():
    try:
        value = float(num1.get()) * float(num2.get())
        res.set(value)
    except:
        error_Msg('error')

def div():
    if num2.get() == "0":
        error_Msg("Division Error")
    elif num2.get() != "0":
        try:
            value = float(num1.get()) / float(num2.get())
            res.set(value)
        except:
            error_Msg('error')

def clear():
    num1.set("")
    num2.set("")
    res.set("")

def creator():
    tkinter.messagebox.showinfo("Creator", "calculator has been created by Mohammad Ali Malekzadeh.")

# %% [markdown]
# # Label & Entrys

# %%
label_first_num = Label(First_frame, text= "Enter First Number:", bg= color)
label_first_num.pack(side= LEFT, padx= 5, pady= 5)
first_num = Entry(First_frame, highlightbackground= color, textvariable= num1)
first_num.pack(side= LEFT)
label_second_num = Label(Second_frame, text= "Enter Second Number:", bg= color)
label_second_num.pack(side= LEFT, padx= 5, pady= 5)
second_num = Entry(Second_frame, highlightbackground= color, textvariable= num2)
second_num.pack(side= LEFT)
num_result = Label(Third_frame, text= "Result", bg= color)
num_result.pack(side= LEFT, padx=5, pady=5)
result = Entry(Third_frame, highlightbackground= color, textvariable=res)
result.pack(side= LEFT, padx=5, pady=5)

# %% [markdown]
# # Run

# %%
root.mainloop()
